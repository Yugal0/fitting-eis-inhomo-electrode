# %%
import matplotlib.pyplot as plt
import numpy as np

data = [[ 1.67989, 174296,  7.5131, 5.77908,  3.2015],
        [ 58230, 381139,  780.45,  99308, 160454],
        [ 89135,  80552, 1.52558, 497981, 603535],
        [ 78415,  8.1858, 15.0656, 193263,  69638],
        [139361, 3.31509, 343164, 781.380,  52269]]

# plt.figure(frameon=False)
plt.axis('off')
plt.table(data,rowLabels=["A","B","C","D","E"],loc="center")
np.around(data,decimals=3,out=None)
data
# Out:
# [[1.67989, 174296, 7.5131, 5.77908, 3.2015],
#  [58230, 381139, 780.45, 99308, 160454],
#  [89135, 80552, 1.52558, 497981, 603535],
#  [78415, 8.1858, 15.0656, 193263, 69638],
#  [139361, 3.31509, 343164, 781.38, 52269]]

# %%
fig, ax = plt.subplots()
ax.plot(range(10))
axin1 = ax.inset_axes([0.8, 0.1, 0.15, 0.15])
axin2 = ax.inset_axes(
        [5, 7, 2.3, 2.3], transform=ax.transData)

# %%
import decimal
decimal.getcontext().prec=10

decimal.Decimal(eval("1+0.00010078"))
# Out:
# Decimal('1.000100779999999911495933702099137008190155029296875')
