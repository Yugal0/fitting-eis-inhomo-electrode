# %%
from scipy.special import gamma
import numpy as np
import matplotlib.pyplot as plt
t=np.linspace(0,1000,1000)
plt.plot(t,1*(1e-6)*t**(1-0.9)/gamma(1-0.9))
plt.xlabel("Time (s)")
plt.ylabel("Charge (Columb)")
plt.grid(True)
#plt.plot(t,t**(1-0.8))
#plt.ylim(0,)
gamma(0)
# Out:
# inf
